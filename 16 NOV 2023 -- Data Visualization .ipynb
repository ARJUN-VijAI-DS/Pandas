# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <font size = 5.5 > **Data Visualization**: is the presentation of Data in a graphical or pictorial format. It involves creating visual representation of Data to identify patterns, trends and insights that may not be apparent in **Raw Data**.

# %% [markdown]
# <font size = 4.5> Library.... 1. matplotlib  2. seaborn

# %% [markdown]
# <font size = 5.5> **Matplotlib** -- <br><br> Matplotlib is a comprehensive library for creating static, animated and interactive visualization in PYthon.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# <font size = 5.5 > A **"figure"** means the entire image containing all the subplots. "Axes" refers to the individual subplots.

# %%
fig,ax = plt.subplots()
print(fig,ax)
# Out:
# Figure(640x480) Axes(0.125,0.11;0.775x0.77)

# %%
fig,ax = plt.subplots()
print(fig)
# Out:
# Figure(640x480)

# %%
fig,ax = plt.subplots()
print(ax)
# Out:
# Axes(0.125,0.11;0.775x0.77)

# %%
## You can change the figure size.
fig1,a1 = plt.subplots(2,5)
print(fig1,a1)
# Out:
# Figure(640x480) [[<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]]

# %%
### You can create  many axes(subpolts) in a single figure....
fig2,(ax1,ax2) = plt.subplots(nrows = 2, ncols = 1, figsize(5,5))
# Out:
#   Cell In[15], line 2
#     fig2,(ax1,ax2) = plt.subplots(nrows = 2, ncols = 1, figsize(5,5))
#                                                                     ^
# SyntaxError: positional argument follows keyword argument

# %%
### You can create  many axes(subpolts) in a single figure....
fig2,(ax1,ax2) = plt.subplots(nrows = 2, ncols = 1, figsize=(5,5))

# %%
fig2

# %%
ax1,ax2
# Out:
# (<Axes: >, <Axes: >)

# %%
print(ax1,ax2)
# Out:
# Axes(0.125,0.53;0.775x0.35) Axes(0.125,0.11;0.775x0.35)

# %%
type(fig2),type(ax1)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %%
### You can create  many axes(subpolts) in a single figure....
fig3,((aa1,aa2),(aa3,aa4)) = plt.subplots(nrows = 2, ncols = 2, figsize=(3,3))

# %%
### You can create  many axes(subpolts) in a single figure....
fig4,((b1,b2),(b3,b4),(b5,b6)) = plt.subplots(nrows = 3, ncols = 2, figsize=(3,3))

# %%
### You can create  many axes(subpolts) in a single figure....
fig5,((bb1,bb2),(bb3,bb4),(bb5,bb6)) = plt.subplots(nrows = 3, ncols = 3, figsize=(3,3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 ### You can create  many axes(subpolts) in a single figure....
# ----> 2 fig5,((bb1,bb2),(bb3,bb4),(bb5,bb6)) = plt.subplots(nrows = 3, ncols = 3, figsize=(3,3))
#
# ValueError: too many values to unpack (expected 2)

# %%
### You can create  many axes(subpolts) in a single figure....
fig6,((c1,c2,c3),(c4,c5,c6),(c7,c8,c9)) = plt.subplots(nrows = 3, ncols = 3, figsize=(7,7))

# %%
### You can create  many axes(subpolts) in a single figure....
fig7,((d1,d2,d3),(d4,d5,d6),(d7,d8,d9)) = plt.subplots(nrows = 3, ncols = 3, figsize=(7,5))

# %%
fig7

# %%
fig7,((d1),(0,0))
# Out:
# (<Figure size 700x500 with 9 Axes>, (<Axes: >, (0, 0)))

# %%
print(fig7,((d1),(0,0)))
# Out:
# 0 (0, (0, 0))

# %%
fig7,((d1)) = (0,0)
fig7
# Out:
# 0

# %%
fig7[d1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 fig7[d1]
#
# TypeError: 'Figure' object is not subscriptable

# %%
fig7[0,0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 fig7[0,0]
#
# TypeError: 'Figure' object is not subscriptable

# %%
fig7[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 fig7[0]
#
# TypeError: 'Figure' object is not subscriptable

# %%
fig7[(d1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 fig7[(d1)]
#
# TypeError: 'Figure' object is not subscriptable

# %%
fig7,(d1)
# Out:
# (<Figure size 700x500 with 9 Axes>, <Axes: >)

# %%
print(fig7,(d1))
# Out:
# Figure(700x500) Axes(0.125,0.653529;0.227941x0.226471)

# %%
fig7,((d1))
# Out:
# (<Figure size 700x500 with 9 Axes>, <Axes: >)

# %%
fig7,((d1(0,0)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 fig7,((d1(0,0)))
#
# TypeError: 'Axes' object is not callable

# %%
fig7[::d1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 fig7[::d1]
#
# TypeError: 'Figure' object is not subscriptable

# %%
fig7.d1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fig7.d1
#
# AttributeError: 'Figure' object has no attribute 'd1'

# %%
fig,ax = plt.subplots(5,5)
print(fig,ax)
# Out:
# Figure(640x480) [[<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]
#  [<Axes: > <Axes: > <Axes: > <Axes: > <Axes: >]]

# %%
help(fig7)
# Out:
# Help on Figure in module matplotlib.figure object:
#
# class Figure(FigureBase)
#  |  Figure(figsize=None, dpi=None, *, facecolor=None, edgecolor=None, linewidth=0.0, frameon=None, subplotpars=None, tight_layout=None, constrained_layout=None, layout=None, **kwargs)
#  |
#  |  The top level container for all the plot elements.
#  |
#  |  Attributes
#  |  ----------
#  |  patch
#  |      The `.Rectangle` instance representing the figure background patch.
#  |
#  |  suppressComposite
#  |      For multiple images, the figure will make composite images
#  |      depending on the renderer option_image_nocomposite function.  If
#  |      *suppressComposite* is a boolean, this will override the renderer.
#  |
#  |  Method resolution order:
#  |      Figure
#  |      FigureBase
#  |      matplotlib.artist.Artist
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getstate__(self)
#  |
# ...
