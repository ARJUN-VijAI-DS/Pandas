# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
# Histogram.........
fig,ax = plt.subplots(figsize = (10,5))
np.random.seed(12)
a = np.random.randint(100, size = 80) ### Generates 80 random integers between 0 and 100 (100 is exclusive or excluded...)
ax.hist(a, bins = 10)
ax.set_title("Random Generation")
# Out:
# Text(0.5, 1.0, 'Random Generation')
