# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
help(ax.pie)
# Out:
# Help on method pie in module matplotlib.axes._axes:
#
# pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, hatch=None, data=None) method of matplotlib.axes._axes.Axes instance
#     Plot a pie chart.
#
#     Make a pie chart of array *x*.  The fractional area of each wedge is
#     given by ``x/sum(x)``.
#
#     The wedges are plotted counterclockwise, by default starting from the
#     x-axis.
#
#     Parameters
#     ----------
#     x : 1D array-like
#         The wedge sizes.
#
#     explode : array-like, default: None
#         If not *None*, is a ``len(x)`` array which specifies the fraction
#         of the radius with which to offset each wedge.
#
#     labels : list, default: None
#         A sequence of strings providing the labels for each wedge
#
# ...

# %%
### Pie Chart
Labels = ["Samsung", "Oppo", "Oneplus", "Redmi"]
Share = [35,30,15,20]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Share,abels, autopct = "%1.2f")
ax.set_title("Market Share")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 Share = [35,30,15,20]
#       4 fig,ax = plt.subplots(figsize = (5,5))
# ----> 5 ax.pie(Share,Labels, autopct = "%1.2f")
#       6 ax.set_title("Market Share")
#
# File e:\Users\user\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# ...

# %%
### Pie Chart
Company = ["Samsung", "Oppo", "Oneplus", "Redmi"]
Share = [35,30,15,20]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Share,labels = Company, autopct = "%1.2f")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
### Pie Chart
Company = ["Samsung", "Oppo", "Oneplus", "Redmi"]
Share = [35,30,15,20]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Share,labels = Company, autopct = "%2.4f")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
### Pie Chart
Company = ["Samsung", "Oppo", "Oneplus", "Redmi"]
Share = [10000,40000,30000,50000]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Share,labels = Company, autopct = "%2.4f")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
### Pie Chart
Company = ["Samsung", "Oppo", "Oneplus", "Redmi"]
Share = [10000,40000,30000,50000]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Share,labels = Company, autopct = "%100.4f")            #####   Changing values here
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
### Pie Chart
Company = ["Samsung", "Oppo", "Oneplus", "Redmi"]
Share = [10000,40000,30000,50000]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Share,labels = Company, autopct = "%200.4f")            #####   Changing values here
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
#### Pie Chart
Company = ["Samsung", "Redmi", "OnePlus", "Oppo"]
Size = [320,20,15,25]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Size, labels = Company, autopct = "%1.3f%%")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
#### Pie Chart
Company = ["Samsung", "Redmi", "OnePlus", "Oppo"]
Size = [320,20,15,25]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Size, labels = Company, autopct = "%1.5f%%")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
#### Pie Chart
Company = ["Samsung", "Redmi", "OnePlus", "Oppo"]
Size = [320,20,15,25]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Size, labels = Company, autopct = "%1.5f")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')

# %%
#### Pie Chart
Company = ["Samsung", "Redmi", "OnePlus", "Oppo"]
Size = [320,20,15,25]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Size, labels = Company, autopct = "%1.5f%")
ax.set_title("Market Share")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       3 Size = [320,20,15,25]
#       4 fig,ax = plt.subplots(figsize = (5,5))
# ----> 5 ax.pie(Size, labels = Company, autopct = "%1.5f%")
#       6 ax.set_title("Market Share")
#
# File e:\Users\user\anaconda3\lib\site-packages\matplotlib\__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# ...

# %%
#### Pie Chart
Company = ["Samsung", "Redmi", "OnePlus", "Oppo"]
Size = [320,20,15,25]
fig,ax = plt.subplots(figsize = (5,5))
ax.pie(Size, labels = Company, autopct = "%1.5f%%")
ax.set_title("Market Share")
# Out:
# Text(0.5, 1.0, 'Market Share')
